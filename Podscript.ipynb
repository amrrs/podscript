# %%
# !nvidia-smi
# Out:
# Mon Sep 26 18:09:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/openai/whisper.git  -q
# !pip install gradio -q
# Out:
#      |████████████████████████████████| 4.9 MB 38.5 MB/s
#      |████████████████████████████████| 6.6 MB 56.3 MB/s
#      |████████████████████████████████| 120 kB 60.7 MB/s
#   Building wheel for whisper (setup.py) ... done
#      |████████████████████████████████| 5.3 MB 32.8 MB/s
#      |████████████████████████████████| 55 kB 3.3 MB/s
#      |████████████████████████████████| 54 kB 3.4 MB/s
#      |████████████████████████████████| 57 kB 5.3 MB/s
#      |████████████████████████████████| 2.3 MB 57.2 MB/s
#      |████████████████████████████████| 112 kB 73.6 MB/s
#      |████████████████████████████████| 212 kB 65.6 MB/s
#      |████████████████████████████████| 84 kB 3.3 MB/s
#      |████████████████████████████████| 270 kB 68.8 MB/s
#      |████████████████████████████████| 84 kB 3.3 MB/s
#      |████████████████████████████████| 63 kB 2.4 MB/s
#      |████████████████████████████████| 80 kB 8.6 MB/s
#      |████████████████████████████████| 68 kB 7.6 MB/s
#      |████████████████████████████████| 43 kB 2.0 MB/s
#      |████████████████████████████████| 594 kB 64.1 MB/s
#      |████████████████████████████████| 4.0 MB 57.6 MB/s
#      |████████████████████████████████| 856 kB 55.7 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
import whisper
from whisper.utils import write_vtt
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
model = whisper.load_model("medium") #tiny, small, base, medium, large
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:17<00:00, 87.4MiB/s]

# %%
link = "https://podcasts.google.com/feed/aHR0cHM6Ly9mZWVkczIuZmVlZGJ1cm5lci5jb20vdGVkdGFsa3NfYXVkaW8/episode/ZW4uYXVkaW8udGFsay50ZWQuY29tOjk3NDA4?sa=X&ved=0CAUQkfYCahgKEwiQuOnlr7L6AhUAAAAAHQAAAAAQiwc"

# %%
import requests
import re

# %%
content = requests.get(link)

# %%
podcast_url = re.findall("(?P<url>\;https?://[^\s]+)", content.text)[0].split(';')[1]

# %%
podcast_url
# Out:
# 'https://dts.podtrac.com/redirect.mp3/download.ted.com/talks/EnzoRomero_2022U.mp3?apikey=172BB350-0207&amp'

# %%
# !wget -O podcast.mp3 {podcast_url}
# Out:
# /bin/bash: amp: command not found
# --2022-09-26 18:20:15--  https://dts.podtrac.com/redirect.mp3/download.ted.com/talks/EnzoRomero_2022U.mp3?apikey=172BB350-0207
# Resolving dts.podtrac.com (dts.podtrac.com)... 35.82.73.139, 52.24.58.144, 44.238.241.40
# Connecting to dts.podtrac.com (dts.podtrac.com)|35.82.73.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://download.ted.com/talks/EnzoRomero_2022U.mp3?apikey=172BB350-0207 [following]
# --2022-09-26 18:20:16--  https://download.ted.com/talks/EnzoRomero_2022U.mp3?apikey=172BB350-0207
# Resolving download.ted.com (download.ted.com)... 54.210.64.168, 3.215.128.38
# Connecting to download.ted.com (download.ted.com)|54.210.64.168|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dts.podtrac.com/redirect.mp3/dovetail.prxu.org/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/EnzoRomero_2022U_VO_Intro.mp3 [following]
# --2022-09-26 18:20:18--  https://dts.podtrac.com/redirect.mp3/dovetail.prxu.org/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/EnzoRomero_2022U_VO_Intro.mp3
# Connecting to dts.podtrac.com (dts.podtrac.com)|35.82.73.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dovetail.prxu.org/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/EnzoRomero_2022U_VO_Intro.mp3 [following]
# --2022-09-26 18:20:19--  https://dovetail.prxu.org/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/EnzoRomero_2022U_VO_Intro.mp3
# Resolving dovetail.prxu.org (dovetail.prxu.org)... 44.236.140.75, 52.33.56.62, 34.212.75.3, ...
# Connecting to dovetail.prxu.org (dovetail.prxu.org)|44.236.140.75|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dovetail3-cdn.prxu.org/usw2/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/4_i0GO7_l9-QfZseVG1VMCevEAfoaMDEZjHFY1dheV0/EnzoRomero_2022U_VO_Intro.mp3?le=5jFZ8dx0W5PXXse8idCWQ8GVGK6ay8vbaxluYINZO-o&exp=1664302820 [following]
# --2022-09-26 18:20:20--  https://dovetail3-cdn.prxu.org/usw2/70/1ebf1923-1f21-455d-9520-2319f2b9f17c/4_i0GO7_l9-QfZseVG1VMCevEAfoaMDEZjHFY1dheV0/EnzoRomero_2022U_VO_Intro.mp3?le=5jFZ8dx0W5PXXse8idCWQ8GVGK6ay8vbaxluYINZO-o&exp=1664302820
# Resolving dovetail3-cdn.prxu.org (dovetail3-cdn.prxu.org)... 52.84.251.57, 52.84.251.39, 52.84.251.69, ...
# Connecting to dovetail3-cdn.prxu.org (dovetail3-cdn.prxu.org)|52.84.251.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4132449 (3.9M) [audio/mpeg]
# Saving to: ‘podcast.mp3’
#
# podcast.mp3         100%[===================>]   3.94M  --.-KB/s    in 0.04s
#
# 2022-09-26 18:20:20 (94.9 MB/s) - ‘podcast.mp3’ saved [4132449/4132449]

# %%
result = model.transcribe('podcast.mp3')
# Out:
# Detected language: English
# 100%|██████████| 40491/40491 [01:05<00:00, 620.38frames/s]

# %%
with open('sub.vtt', "w") as txt:
  write_vtt(result["segments"], file=txt)

# %%
with open('sub.vtt', "r") as txt:
 print('\n'.join(txt.readlines()))
# Out:
# WEBVTT
#
#
#
# 00:00.000 --> 00:05.440
#
#  It's TED Talks Daily.
#
#
#
# 00:05.440 --> 00:07.920
#
#  I'm Elise Hugh.
#
#
#
# 00:07.920 --> 00:12.560
#
#  Prosthetics have advanced so much in recent years, but for amputees around the world,
#
#
#
# 00:12.560 --> 00:15.960
#
#  they're still often way too expensive.
#
#
#
# 00:15.960 --> 00:21.940
#
#  In his talk from TED 2022, bionic innovator Enzo Romero shares how he's found unconventional
#
#
#
# 00:21.940 --> 00:26.940
#
#  solutions to get more advanced prosthetics to the people who need them.
#
#
#
# 00:26.940 --> 00:30.600
#
#  He makes them more affordable and functional.
#
#
#
# 00:30.600 --> 00:36.000
#
#  Have you ever wondered what makes great minds tick?
#
#
#
# 00:36.000 --> 00:40.820
#
#  I'm Adam Grant, and on my new podcast, Rethinking, I'm trying to find the answers.
#
#
#
# 00:40.820 --> 00:44.220
#
#  Every week, I interview some of my favorite thinkers to learn how we can bring out the
#
#
#
# 00:44.220 --> 00:46.120
#
#  best in ourselves and others.
#
#
#
# 00:46.120 --> 00:52.400
#
#  I talk to death-defying rock climbers, Oscar-winning filmmakers, creators like Lin-Manuel Miranda,
#
#
#
# 00:52.400 --> 00:56.200
#
#  entrepreneurs like Mark Cuban, and thought leaders like Brene Brown.
#
#
#
# 00:56.200 --> 01:03.280
#
#  Find Rethinking on Apple Podcasts, Spotify, Amazon Music, or wherever you listen.
#
#
#
# 01:03.280 --> 01:05.320
#
#  Do you have a TED Talk in you?
#
#
#
# 01:05.320 --> 01:10.040
#
#  The TED Idea Search Southeast Asia 2022 has launched.
#
#
#
# 01:10.040 --> 01:14.160
#
#  Applications are open until September 30th to anyone living in or descended from Southeast
#
#
#
# 01:14.160 --> 01:15.160
#
#  Asia.
#
#
#
# 01:15.160 --> 01:17.160
#
#  Winners will be invited to give a TED Talk.
#
#
#
# 01:17.160 --> 01:20.480
#
#  At this time, we are only accepting applications in English.
#
#
#
# 01:20.480 --> 01:25.320
#
#  Learn more at go.ted.com flash idea search.
#
#
#
# 01:25.320 --> 01:29.320
#
#  Running seven people around the world has some kind of disability.
#
#
#
# 01:29.320 --> 01:34.120
#
#  Being born without my right hand has defined who I am over the past 30 years.
#
#
#
# 01:34.120 --> 01:38.600
#
#  I was fortunate to grow in the sacred valley of the Incas in Cusco, Peru, surrounded by
#
#
#
# 01:38.600 --> 01:43.800
#
#  people who weren't surprised to see me driving my bike or probably playing basketball.
#
#
#
# 01:43.800 --> 01:48.480
#
#  When I was seven, I remember being stunned after I watched Star Wars, The Empire Strikes
#
#
#
# 01:48.480 --> 01:53.280
#
#  Back, when Luke's hand gets cut off, the same one I didn't have.
#
#
#
# 01:53.280 --> 01:58.280
#
#  But then being twice as stunned when the medical robots fitted him with a prosthesis that could
#
#
#
# 01:58.280 --> 02:00.680
#
#  move and feel.
#
#
#
# 02:00.680 --> 02:05.240
#
#  From then on, no greater purpose lived in my mind, which was to have a prosthesis like
#
#
#
# 02:05.240 --> 02:07.760
#
#  Luke Skywalker.
#
#
#
# 02:07.760 --> 02:12.520
#
#  This dream led me to study mechatronics engineering and access the biomechanics and applied robotics
#
#
#
# 02:12.520 --> 02:18.240
#
#  laboratory in Pontifical Catholic University of Peru, where with a multidisciplinary team,
#
#
#
# 02:18.240 --> 02:22.200
#
#  we develop a myoelectric prosthesis for long transradial amputation.
#
#
#
# 02:22.200 --> 02:24.200
#
#  Making me the pilot user.
#
#
#
# 02:24.200 --> 02:26.800
#
#  I was able to move each finger individually.
#
#
#
# 02:26.800 --> 02:31.480
#
#  And also, we develop a way in which we get to pass the sensation from the fingertips
#
#
#
# 02:31.480 --> 02:35.280
#
#  into my forearm using haptic feedback system.
#
#
#
# 02:35.280 --> 02:39.720
#
#  Since this was a research project, we had enough funding to buy stuff from abroad.
#
#
#
# 02:39.720 --> 02:43.760
#
#  So for example, the motors here were all brought by Switzerland.
#
#
#
# 02:43.760 --> 02:50.980
#
#  This is one of the main reasons why it will cost at least $40,000 to make this prosthesis.
#
#
#
# 02:50.980 --> 02:56.640
#
#  But $40,000 is way too much considering that four out of five people with upper limb amputation
#
#
#
# 02:56.640 --> 02:59.000
#
#  live in development countries.
#
#
#
# 02:59.000 --> 03:04.720
#
#  Even the $25,000 that costs a robotic prosthesis imported from abroad is way too much.
#
#
#
# 03:04.720 --> 03:10.000
#
#  In Peru, that is equivalent to work full time on a minimum wage for almost seven years just
#
#
#
# 03:10.000 --> 03:11.000
#
#  to buy the prosthesis.
#
#
#
# 03:11.000 --> 03:13.760
#
#  Never mind pay for your food or your house.
#
#
#
# 03:13.760 --> 03:19.160
#
#  It is often that people get injured while doing manual labor activities like farming
#
#
#
# 03:19.160 --> 03:21.800
#
#  or metal manufacturing.
#
#
#
# 03:21.800 --> 03:28.000
#
#  Getting back to work and having access to money demands a functional hand.
#
#
#
# 03:28.000 --> 03:33.040
#
#  It took me time to realize what a huge privilege I had to study a career that would help fulfill
#
#
#
# 03:33.040 --> 03:34.040
#
#  my dreams.
#
#
#
# 03:34.040 --> 03:39.920
#
#  But actually, what was preventing me from developing a solution that was both affordable
#
#
#
# 03:39.920 --> 03:41.440
#
#  and functional?
#
#
#
# 03:41.440 --> 03:46.080
#
#  The very first step in order to reduce the cost was to reduce the number of motors because
#
#
#
# 03:46.080 --> 03:49.200
#
#  they were all imported and therefore expensive.
#
#
#
# 03:49.200 --> 03:55.960
#
#  So we get to arrange occupational focus groups with our amputee volunteers in order to identify
#
#
#
# 03:55.960 --> 04:00.300
#
#  which gestures they will use the most and of those how many we could perform using just
#
#
#
# 04:00.300 --> 04:01.880
#
#  a single motor.
#
#
#
# 04:01.880 --> 04:03.880
#
#  The answer was three.
#
#
#
# 04:03.880 --> 04:07.760
#
#  Pinch, cylindrical, and lateral.
#
#
#
# 04:07.760 --> 04:11.420
#
#  This also helps us to reduce the number of electromyographic sensors too.
#
#
#
# 04:11.420 --> 04:15.500
#
#  From an arrangement of eight, we pass just to one.
#
#
#
# 04:15.500 --> 04:20.800
#
#  In this way, between mixed inner mechanical and my electric prosthesis, the prices will
#
#
#
# 04:20.800 --> 04:23.000
#
#  be dramatically low.
#
#
#
# 04:23.000 --> 04:25.740
#
#  But material prices matter too.
#
#
#
# 04:25.740 --> 04:31.140
#
#  And that's why we choose to 3D print our prosthesis using mainly plastic from recycled bottles.
#
#
#
# 04:31.140 --> 04:35.280
#
#  In order to develop our prosthesis, the process will go like this.
#
#
#
# 04:35.280 --> 04:40.280
#
#  First, we'll use our 3D scan and our own parameterization software in order to take the measures of the
#
#
#
# 04:40.280 --> 04:43.560
#
#  amputated area and the other hand of the user.
#
#
#
# 04:43.560 --> 04:48.120
#
#  Then we'll recreate the entire set of fingers, the palm, and the prosthesis socket in our
#
#
#
# 04:48.120 --> 04:52.920
#
#  computational model to finally 3D print each of those parts.
#
#
#
# 04:52.920 --> 04:56.320
#
#  So far, in lab Bionics, we have two types of prosthesis.
#
#
#
# 04:56.320 --> 05:01.640
#
#  Machie, which is a mechanical activation, and Pisco with electronic activation.
#
#
#
# 05:01.640 --> 05:06.880
#
#  Pisco costs just 10% of an imported robotic prosthesis that will come from abroad.
#
#
#
# 05:06.880 --> 05:12.000
#
#  This means that even more working class people can access to our technology.
#
#
#
# 05:12.000 --> 05:18.800
#
#  For me, this has been a path where I was able to develop this in my company, lab Bionics.
#
#
#
# 05:18.800 --> 05:24.320
#
#  So for example, take Franco, which now is using his transradial Machie prosthesis in
#
#
#
# 05:24.320 --> 05:29.360
#
#  order to get back to work with his providers on the jungle farm he has.
#
#
#
# 05:29.360 --> 05:34.340
#
#  I am certain that we are able to be on the side with technology that is brought from
#
#
#
# 05:34.340 --> 05:38.480
#
#  abroad to our region, being sold in a very expensive way.
#
#
#
# 05:38.480 --> 05:44.480
#
#  We have the capacity to develop our own technology, having the necessities of our people in mind.
#
#
#
# 05:44.480 --> 05:50.480
#
#  So then people with disabilities and limited resources could live a life again.
#
#
#
# 05:50.480 --> 05:57.680
#
#  For me, when people, our users, get back to work on their places, that look of compassion
#
#
#
# 05:57.680 --> 05:59.760
#
#  changed to astonishment.
#
#
#
# 05:59.760 --> 06:04.780
#
#  The same astonishment which I had when I saw Luke Skywalker's prosthesis.
#
#
#
# 06:04.780 --> 06:10.180
#
#  So this began as a path for myself, but it now belongs to my entire region.
#
#
#
# 06:10.180 --> 06:12.440
#
#  Would you like to join us?
#
#
#
# 06:12.440 --> 06:16.640
#
#  Thank you so much.
#
#
#
# 06:16.640 --> 06:20.680
#
#  TED Talks Daily is hosted by me, Elise Huw, and produced by TED.
#
#
#
# 06:20.680 --> 06:25.040
#
#  The music is from Allison Leighton Brown, and our mixer is Christopher Faisy Bogan.
#
#
#
# 06:25.040 --> 06:30.100
#
#  We record the talks at TED events we host, or from TEDx events, which are organized independently
#
#
#
# 06:30.100 --> 06:32.800
#
#  by volunteers all over the world.
#
#
#
# 06:32.800 --> 06:34.320
#
#  And we'd love to hear from you.
#
#
#
# 06:34.320 --> 06:38.320
#
#  Give us a review on Apple podcasts or email us at podcasts at ted.com.

# %%
import gradio as gr 
import whisper
from whisper.utils import write_vtt
import requests
import os
import re

#model = whisper.load_model("medium")

def inference(link):
  content = requests.get(link)
  podcast_url = re.findall("(?P<url>\;https?://[^\s]+)", content.text)[0].split(';')[1]
  print(podcast_url)
  

  download = requests.get(podcast_url)

  with open('podcast.mp3', 'wb') as f:
    f.write(download.content)

  result = model.transcribe('podcast.mp3')

  with open('sub.vtt', "w") as txt:
    write_vtt(result["segments"], file=txt)

  return (result['text'], 'sub.vtt')

  


title="PodScript"
description="Get Podcast Transcript"
block = gr.Blocks()

with block:
    gr.HTML(
        """     <center> 
                <h1>PodScript</h1>
                <img src = 'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.newbreedmarketing.com%2Fhs-fs%2Fhubfs%2Fshutterstock_1125707303.jpg%3Fwidth%3D5000%26name%3Dshutterstock_1125707303.jpg&f=1&nofb=1&ipt=0ba3d9b639d63b0b737ea63cd81b241cc47f46cb519ac4ca18fd3ce6fc1376ad&ipo=images' width = '50%'></img>
                </center>
        """
    )
    with gr.Group():
        with gr.Box():
          
          link = gr.Textbox(label="Google Podcasts Link")

          with gr.Row().style(mobile_collapse=False, equal_height=True): 
              btn = gr.Button("Get PodScript 🪄")
          
          text = gr.Textbox(
              label="PodScript", 
              placeholder="PodScript Output",
              lines=5)
          
          transcription = gr.File()     
       
          
          btn.click(inference, inputs=[link], outputs=[text,transcription])

block.launch(debug=True, enable_queue = True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://11296.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://11296.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# https://dts.podtrac.com/redirect.mp3/download.ted.com/talks/WanuriKahiu_2017U.mp3?apikey=172BB350-0207&amp
# Detected language: English
# 100%|██████████| 36651/36651 [00:49<00:00, 736.41frames/s]
# Keyboard interruption in main thread... closing server.
# (<gradio.routes.App at 0x7f09107ca350>,
#  'http://127.0.0.1:7860/',
#  'https://11296.gradio.app')
